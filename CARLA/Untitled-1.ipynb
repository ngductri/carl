# %%
# Cell 1: imports and small helpers
import os
import math
import numpy as np
import h5py
import cv2 as cv
import matplotlib.pyplot as plt
from IPython.display import display
plt.rcParams['figure.dpi'] = 120

# small plot helper
def imshow(img, ax=None, title=None):
    if ax is None:
        plt.figure(figsize=(5,5))
        plt.imshow(img)
        plt.axis('off')
        if title: plt.title(title)
        plt.show()
    else:
        ax.imshow(img)
        ax.axis('off')
        if title: ax.set_title(title)

# %%
# Cell 2: set path to your TownXX.h5
# Replace with the real path where you stored the maps created by birdview_map_opencv.py
H5_PATH = 'team_code\birds_eye_view\maps_2ppm_cv\Town01.h5'   # <<-- edit this path if needed (or upload file in the notebook)
assert os.path.exists(H5_PATH), f"File not found: {H5_PATH}. Upload or change path and re-run."
print("Found file:", H5_PATH)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Cell 2: set path to your TownXX.h5
#       2 # Replace with the real path where you stored the maps created by birdview_map_opencv.py
#       3 H5_PATH = 'Town01.h5'   # <<-- edit this path if needed (or upload file in the notebook)
# ----> 4 assert os.path.exists(H5_PATH), f"File not found: {H5_PATH}. Upload or change path and re-run."
#       5 print("Found file:", H5_PATH)
#
# AssertionError: File not found: Town01.h5. Upload or change path and re-run.
